# %%
#Docstring
"""
In Superbowl 51, the New England Patriots were trailing 28-3, then they turned it on 
and scored 25 points in the 4th quarter to take it to extra time and win the game 28-34. 
During this comeback, they had to convert multiple 4th down plays to score. 
This game is based on the user being the New England Patriots head coach and making crucial 4th down and goal decisions. 
The game consists of 3-5 levels and the users play call decisions will determine how far they get in the game. 
The Patriots also had luck on their side which will also factor into this game  
The rounds of this game consist of:


Round 1: Play call 1
Round 2: Play call 2
Round 3:Play call 3  
Round 4: Play call 4
Round 5:Coin toss and or Playcall 5 (Depending on your Luck)

B.) Known Bugs and/or Errors:
Spelling 
"""

#Importing Packages
import time
from colorama import Fore, Back
import random
import sys 


# Welcome Message
print(Fore.BLACK +'-'*50)
print(Fore.RED +"""Welcome to the 2017 superbowl at the NRG Stadium in Houston """)
print(Fore.YELLOW +'-'*50)
time.sleep(3)
print(Fore.WHITE + Back.BLUE + """ We are well poised for one of the best fourth quarters in superbowl history""")
print(Fore.RESET + Back.RESET)


# Instructions
time.sleep(2)
print("""\nInstructions for the game: \t 
\nToday you will be playing the role of a nfl head coach of New England Patriots. 
\nYou will be asked to make offensive playcalls which will determine if your team scores
\nNot to mention the prestige Vince Lombardi Trophy and a superbowl ring""")
time.sleep(1)
print("""\none important instruction to follow,
\nFor every scenario please in the game please input one the following if you choose pass:
\n'1','pass','option 1','pass play'
\nif you choose run then input one of the following:
\n'2','run','option 2','run play'""")
time.sleep(0.5)
print("""Failure to do so in the first attempt will give you a warning
\nyou will then be aksed to try again
\nfailure to do so in the second attempt will eject you from the game and you will lose
\nand if you lose you won't be able to restart 
\njust like in a real superbowl""")
time.sleep(0.5)
print("Good luck!")
time.sleep(0.5)


print("""\nJust a quick question before we get started
\nplease input 'yes','y','No','N'""")

#intro question list
question_1_option_1=['yes','y','Y''YES']
question_1_option_2=['no','n','N','NO']


# fail function 
def fail():
    print("""\nUnfortunately that is the end of the game 
    \nbetter luck next time """)
    time.sleep(0.5)
    print("""\nThank you for playing Americas game""")
    sys.exit()
    
#invalid input 
def invalid_input():
    print("""Since you failed to follow instructions, you have been kicked out of the game
    \nYou have lost the superbowl by forfeit""")
    sys.exit()

#level 16 
def level_16():
    time.sleep(3)
    print(Fore.BLUE +'-'*50)
    time.sleep(0.9)
    print(Fore.WHITE +'-'*50)
    time.sleep(0.9)
    print(Fore.RED +'-'*50)
    time.sleep(0.9)    
    #patriots level 16 intro 
    print("""\nWelcome to extra time here in superbowl 51
    \nYou have made an extraordinary comeback here 
    \none more play and you have won the superbowl
    \nyou've won the coin toss and made the decison to take possession of the ball """)
    #patriots level 16 scenario
    print("""\nYou have once again marched down the field and find yourself in another 4th and goal situation 
    \nThe defense is looking tired and so are your recievers
    \nYour running back looks hungry to take it to the endzone despite the run play not working for the entire game
    \nThe defense has forgotten about the run game and they look focused on stopping your recievers""")
    
    level_16_option_1 = ['1','pass','option 1','pass play']
    level_16_option_2 = ['2','run','option 2','run play']        
    loop=2
    #level 16 choice
    while loop>=0:
        level_16 = input('Do you want to go for a run or pass play?\t') 
    
    #choose pass
        if level_16 in level_16_option_1:
            time.sleep(0.9)
            print(Fore.BLUE+Back.WHTIE+"""\nThat was not the right play call 
            \nThe defense read your play and they were able to read your play""")
            time.sleep(1)
            print("""\nThe opposition got the ball and since you gave the ball away in 4th down situation 
            \nthe opposing offense go the ball and scored a field goal and sadly won the game
            \nthe final score is now 31-28 to the Atlanta Falcons""")
            time.sleep(1)
            fail()
            

    #choose run
        if level_16 in level_16_option_2:
            time.sleep(0.9)

            print(Fore.BLUE +Back.Black +"""\nTOUCHDOWNN!!! 28-31!! """)
            time.sleep(1)
            print("""\nWell done on winning the superbowl, that was remarkable
            \nwhat a comback that was!! Make sure to celebrate!!!""")      
            time.sleep(0.5)
            print("\nThank you for playing Americas game")
            sys.exit()
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
             
 

#coin toss lost 
def lost():
    print("""\nIt was important to win the toss becasue now  the opposition has possession of the ball
    \nThe Atlanta Falcons offense have marched to your endzone and scored
    \nThe score is now 34-28 to the Atlanta Falcons 
    \nAccording to the rules of the National Football League
    \nThe team that scores a touchdown first in overtime wins
    \nThe final score is 34-28 to the falcons""")
    fail()


#decision 
def decision():
    time.sleep(3)
    print(Fore.BLUE +'-'*75)
    time.sleep(0.5)
    print(Fore.WHITE +'-'*75)
    time.sleep(0.5)
    print(Fore.RED +'-'*75)
    time.sleep(0.5)
    #intro 
    print("""\nyou won the toss
    \nThings seem to be going your way
    \nYour offence has built so much momentum 
    \nAnd the oppositon defence looks tired
    \nThe opposition offence is well rested on the bench
    \nNow it's up to you to decide if you want to start on offence or defence
    \nplease input one of the following for defence should you choose that option:
    \n'defence','DEFENCE','2','d','D'
    \nplease input one of the following for offence should you choose that option:
    \n'offence','OFFENCE','1','o','O'
    \nfailure to do so will result in a warning followed by an ejection should you repeat it """)
    
    dec_option_1=['defence','DEFENCE','2','d','D']
    dec_option_2=['offence','OFFENCE','1','o','O']
    loop=2#restricting user invalid input
    #decision input
    while loop>=0:
        decision=input('do you want to start on offence or defence?\t')
        #option1
        if decision in dec_option_1:
            print("""\nThe atlanta falcons offense have marched to your endzone and scored
            \nthe score is now 34-28 to the Atlanta Falcons 
            \naccording to the rules of the National Football League
            \nthe team that scores a touchdown in overtime wins
            \nthe final score is 34-28 to the falcons""")
            fail()
            
        
        #option2   
        elif decision in dec_option_2:
            print("\nNice job!!")
            level_16() 
            
        
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
           


 # coin toss
def flip():
  playing = True
  while playing ==True:
    number = random.randint(1,2)
    guess  = input("heads or tails: ")

    #heads is thrown and guessed 
    if number == 1 and guess =="heads":
      print("\nwell done you won the toss" )
      level_16()
      break
    #tails is thrown and guessed 
    elif number == 2 and guess =="tails":
      print("\nwell done you won the toss")
      level_16()
      break
    #heads is thrown and tails is guessed  
    elif number == 1 and guess =="tails":
      print("\nUnfortunately you lost the toss ")
      lost()
      break
    #tails is thrown and heads is guessed 
    elif number == 2 and guess =="heads":
      print("\nUnfortunately you lost the toss")
      lost()
      break 
    else:
        lost()

                








#level 14
def level_14():
    time.sleep(3)
    print(Fore.BLUE +'-'*50)
    time.sleep(0.9)
    print(Fore.WHITE +'-'*50)
    time.sleep(0.9)
    print(Fore.RED +'-'*50)
    time.sleep(0.9)
    
    #patriots level 14 intro 
 
    print("""\nyou have done well to score two touchdowns 
    \nbut with time running out it looks like the Falcons are going  run away with it so
    make every play count""")
    time.sleep(1)
    print("""\nIt's 4th and goal again so here we go 
    \nThe opoosition defence has lined up in a pass stop defense
    \nBut they also look ready to stop the run and they are expecting it 
    \nDue to your last two plays being pass plays""")
        
    level_14_option_1 = ['1','pass','option 1','pass play']
    level_14_option_2 = ['2','run','option 2','run play']
    loop=2    
    #level 14 choice 
    while loop>=0:#stopping users from invalid input
        level_14 = input('Do you want to go for a run or pass play? \t')
    
    #Choose pass
    if level_14 in level_14_option_1:
        time.sleep(0.9)
        print(Fore.BLUE + Back.BLACK + """\n Another touchdown pass 
        \nthe opposition does not know how to stop the pass
        \non top of that you have scored the 2 point conversion 
        \the score is now 28-25""")
        print(Fore.RESET + Back.RESET)
        time.sleep(2)
        print("""\ngood job scoring on the last play but as you are running out of time
        \the opposing offence has the ball and they can take a knee to run out the clock to 0 
        \the final score is 28-25 to the falcons""")
        time.sleep(2)
        fail()
        
        
              
           
        
    # Choose run
    elif level_14 in level_14_option_2:
        time.sleep(0.9)
        print(Fore.WHITE + Back.BLACK + '\nnot sharp enought to score a touchdown there'
        '\nthe defense is too powerful and still full of energy to allow a runner to get in the endzone'
        '\nthe score is now 28-17.')
        print(Fore.RESET + Back.RESET)
        time.sleep(2)
        print("""\you are running out of time
        \nthe opposing offence has the ball and they can take a knee to run out the clock to 0 
        \nthe final score is 28-17 to the falcons""")
        time.sleep(2)
        fail()
        
        
    #invalid input    
   
    else:
        print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
    loop -= 1
    if loop == 0:
        invalid_input()
        





#level 15 
def level_15():
    time.sleep(3)
    print(Fore.BLUE +'-'*50)
    time.sleep(0.9)
    print(Fore.WHITE +'-'*50)
    time.sleep(0.9)
    print(Fore.RED +'-'*50)
    time.sleep(0.9)
    #patriots level 15 intro 
    print("""\nI think you and your team have done extremely well to get this far 
    \nyou have shown good coaching awareness and completely shifted the momentum
    \nwhich has resulted in you having one hand on the superbowl """)
    #patriots level 15 scenario
    ("""\nWell done on reaching this far
    \nscore a touchdown and the superbowl is yours 
    \nthe defense has not picked up your passing game at all
    \n this is completely your call 
    \nthe clock is running out but this is a 3rd and goal situation
    \nso if you don't score a touchdown, you will get a field goal
    \nthis will take you into extra time.""")
    
    level_15_option_1 = ['1','pass','option 1','pass play']
    level_15_option_2 = ['2','run','option 2','run play']
    loop=2
    
    #Level 15 Choice
    while loop>=0:#stopping users from invalid input
        level_15 = input('Do you want to go for a run or pass play? \t')
    
    #Choose pass
        if level_15 in level_15_option_1:
            time.sleep(0.9)
            print(Fore.BLUE + Back.BLACK + '\nField goal! the defence was able to stop the pass'
            '\nthe score is now 28-28.')
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print(f"""\nwell done on scoring the field goal
            \nthe score is now level and the clock is at 0:00
            \n we are now heading for extra time""")
            time.sleep(2)
            print("""\nWelcome to Superbowl 51 overtime
            \nIt's time for the coin toss
            \nPlease input heads or tails
            \nFailure to do will guarantee you losing the toss""")
            flip()
            
           
        
    # Choose run
        elif level_15 in level_15_option_2:
            time.sleep(0.9)
            print(Fore.WHITE + Back.BLACK + '\nTOUCHDOWN!!! the defence had no answer to stop you'
            '\nthe score is NOW 28-31.')
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print("""\nAn amazing comeback completed at the end of normal time
            \nat the start of the 4th quarter your odds of winning were low 
            \nbut depsite that you managed to show everyone what you and your team can do
            \nCongragulations you are now a superbowl winner""")
            time.sleep(2)
            print(f"\n thank you for playing Americas game")
            sys.exit()
        #invalid syntax 
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
            
            
     


#level 12 
def level_12():
    time.sleep(3)
    print(Fore.BLUE +'-'*50)
    time.sleep(0.9)
    print(Fore.WHITE +'-'*50)
    time.sleep(0.9)
    print(Fore.RED +'-'*50)
    time.sleep(0.9)
    #patritos level 12 intro 
    print("""\nso far you have only had one scoring play 
    \nyou are going to need a bit of a miracle to win this superbowl""")
    #patriots level 12 scenario
    print("""\nanother 4th and goal situation 
    \nthe opposition defence looks poised and ready to stop you from the run
    \nbut with a great QB at the helm they may be thinking you will pass
    \nonetheless they are look like they are still lined up for the run""")
    
    level_12_option_1 = ['1','pass','option 1','pass play']
    level_12_option_2 = ['2','run','option 2','run play']
    loop=2
    #Level 12 Choice
    while loop>0:#stopping users from invalid input
        level_12 = input('Do you want to go for a run or pass play? \t')
    
    #Choose pass
        if level_12 in level_12_option_1:
            time.sleep(0.9)
            print(Fore.BLUE + Back.BLACK + '\nTOUCHDOWN! the defence was a bit bamboozled by you well played'
            '\nthe score is now 28-17.')
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print(f"""\nwell done on scoring that last play but the defense have the ball
            \nwith insuficent amount of time left they have taken a knee and run the clock to 0
            \nthis means that the final score of superbowl 51 is 28-17 to the Falcons
            \better luck next year""")
            time.sleep(2)
            fail()
            
           

    # Choose run
        elif level_12 in level_12_option_2:
            time.sleep(0.9)
            print(Fore.WHITE + Back.BLACK + '\nthe defence had the answer to stop you'
            '\nthe score is still 28-10.')
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print("""\nunlucky on the play there but there is more bad news
            \the defense have the ball and with insifficent time on the clock 
            the falcons are going to take a knee and run the clock to 0 
            \nthis means that the final score of superbowl 51 is 28-10 to the Falcons
            \better luck next year""")
            time.sleep(2)
            fail()
            
           
       #invalid input
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
        
       
#level 13
def level_13():
    time.sleep(3)
    print(Fore.BLUE +'-'*75)
    time.sleep(0.5)
    print(Fore.WHITE +'-'*75)
    time.sleep(0.5)
    print(Fore.RED +'-'*75)
    time.sleep(0.5)
    #patriots level 13 intro
    print("""\nyour team has shown some good fight so far 
    \nbut with time running out, you are going to need some luck""")
    #patriots level 13 scenario 
    print("""\nWe are down to another 4th and goal situation 
    \nthe oppositon looks like they are lined up with some strong linebackers
    \nthey look solid against the run but they also suspect that you may go for the pass
    \nbut they are still persisting with a strong run stop defense""")
    
    level_13_option_1 = ['1','pass','option 1','pass play']
    level_13_option_2 = ['2','run','option 2','run play']
    loop=2
    #Level 13 Choice
    while loop>=0: #stopping users from invalid input
        level_13 = input('Do you want to go for a run or pass play? \t')
    
    #Choose pass
        if level_13 in level_13_option_1:
            time.sleep(0.9)
            print(Fore.BLUE + Back.BLACK + '\nTOUCHDOWN! the defence was a bit bamboozled by you well played'
            '\nthe score is now 28-25.')
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print(f"""\nwell done on scoring that last play but the defense have the ball
            \nhowever with insufficient amount of time left they have taken a knee and ran the clock down to 0
            \nthis means that the final score of superbowl 51 is 28-25 to the Falcons
            \better luck next year""")
            time.sleep(2)
            fail()
            
    # Choose run
        elif level_13 in level_13_option_2:
            time.sleep(0.9)
            print(Fore.WHITE + Back.BLACK + '\nthe defence had the answer to stop you'
            '\nthe score is still 28-17.')
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print("""\nunlucky on the play there but there is more bad news
            \the defense have the ball and with insifficent time on the clock 
            the falcons are going to take a knee and run the clock to 0 
            \nthis means that the final score of superbowl 51 is 28-17 to the Falcons
            \better luck next year""")
            time.sleep(2)
            fail()
            
        #invalid input    
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
            
        


#level 10 
def level_10():
    #superbowl game level 10 
    time.sleep(3)
    print(Fore.BLUE +'-'*50)
    time.sleep(0.9)
    print(Fore.WHITE +'-'*50)
    time.sleep(0.9)
    print(Fore.RED +'-'*50)
    time.sleep(0.9)
    
    #patriots level 10 intro 
    print(f"""\n the game has not at all gone your way so far but you have had a scoring play
    \nHowever you are going to need a lot more luck than that as the superbowl is slowly slipping away""")
    time.sleep(3)
    print(Fore.BLUE)
    #patriots level 10 scenario 
    print("""\nHere we go again, another 4th and goal situation
    \nthe defense is lined up strong to stop the run game 
    \nthey are also confident of stopping the pass game but not as much as the run""")
    
    level_10_option_1 = ['1','pass','option 1','pass play']
    level_10_option_2 = ['2','run','option 2','run play']
    loop=2 #stopping users from invalid input
    #Level 10 Choice
    while loop>=0:
        level_10 = input('Do you want to go for a run or pass play? \t')
    
    #Choose pass
        if level_10 in level_10_option_1:
            time.sleep(0.9)
            print(Fore.BLUE + Back.BLACK + '\nTOUCHDOWN! the defence was a bit bamboozled by you well played'
            '\nthe score is now 28-17.')
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print(f"""\nwell done on scoring that last play but the defense have the ball
            \nwith insuficent amount of time left they have taken a knee and ran the clock down to 0
            \nthis means that the final score of superbowl 51 is 28-17 to the Falcons
            \better luck next year""")
            time.sleep(2)
            fail()
            
        
    # Choose run
        elif level_10 in level_10_option_2:
            time.sleep(0.9)
            print(Fore.WHITE + Back.BLACK + '\nthe defence had the answer to stop you'
            '\nthe score is still 28-10.')
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print("""\nunlucky on the play there but there is more bad news
            \nthe defense have the ball and with insufficent amount of time on the clock 
            \nthe falcons are going to take a knee and run the clock to 0 
            \nthis means that the final score of superbowl 51 is 28-10 to the Falcons
            \better luck next year""")
            time.sleep(2)
            fail() 
            
        #invalid input     
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
            
        

#level 11 
def level_11():
    #superbowl game level 
    time.sleep(3)
    print(Fore.BLUE +'-'*50)
    time.sleep(0.9)
    print(Fore.WHITE +'-'*50)
    time.sleep(0.9)
    print(Fore.RED +'-'*50)
    time.sleep(0.9)
    
    #patriots level 11 intro 
    print(f"""\ngood job on scoring in the last play you have picked up some steam
    \nHowever time is running out so therefore you need to make every play count """)
    time.sleep(3)
    print(Fore.BLUE)
    #patriots level 11 scenario
    print("""\nHere we go again, another 4th and goal situation
    \nthe defense is lined up strong to stop the run game 
    \nthey are also confident of stopping the pass but not as much as the run""")
     
        
    level_11_option_1 = ['1','pass','option 1','pass play']
    level_11_option_2 = ['2','run','option 2','run play']
    loop=2#stopping users from invalid input    
    #Level 11 Choice
    while loop>=2:
        level_11 = input('Do you want to go for a run or pass play? \t')
    
     #Choose pass
        if level_11 in level_11_option_1:
            time.sleep(0.9)
            print(Fore.WHITE + Back.BLACK + '\nTOUCHDOWN! the defence was a bit bamboozled by you well played'
            '\nOn top of that your team scored the 2 point conversion'
            '\nthe score is now 28-25.')
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print(f"""\nwell done on scoring that last play but the defense have the ball
            \nwith insuficent amount of time left they have taken a knee and run the clock to 0
            \nthis means that the final score of superbowl 51 is 28-25 to the Falcons
            \nbetter luck next year""")
            time.sleep(2)
            fail()
            


    # Choose run
        elif level_11 in level_11_option_2:
            time.sleep(0.9)
            print(Fore.WHITE + Back.BLACK + '\nthe defence had the answer to stop you'
            '\nthe score is still 28-17.')
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print("""\nunlucky on the play there but there is more bad news
            \the defense have the ball and with insufficient time on the clock 
            the falcons are going to take a knee and run the clock to 0 
            \nthis means that the final score of superbowl 51 is 28-17 to the Falcons
            \better luck next year""")
            time.sleep(2)
            fail()
            
       #invalid input
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
            
        

#level 8
def level_8():
    #superbowl game level 8
    
    time.sleep(3)
    print(Fore.BLUE +'-'*50)
    time.sleep(0.9)
    print(Fore.WHITE +'-'*50)
    time.sleep(0.9)
    print(Fore.RED +'-'*50)
    time.sleep(0.9)
    #patriots level 8 intro 
    ("""\nIt has been a rough superbowl for you so far
    \nyou do not want to be that team which does not even register a touchdown""")
    time.sleep(3)
    print(Fore.BLUE)
    #patriots level 8 scenario 
    print("""\nIt is 4th and goal again
    \nyou have utilized the run game a lot and it has not worked 
    \nyour recivers are annoyed with your play calling 
    \nHowever since you are the head coach, the play call depends on you""")
    
    level_8_option_1 = ['1','pass','option 1','pass play']
    level_8_option_2 = ['2','run','option 2','run play']
    loop=2#stopping users from invalid input
    #Level 8 Choice
    while loop>=0:
        level_8 = input('Do you want to go for a run or pass play? \t')
    
     #Choose pass
        if level_8 in level_8_option_1:
            time.sleep(0.5)
            print(Fore.BLUE + Back.BLACK + """\nTOUCHDOWN! the defence was a bit bamboozled by you well played'
            '\nthe score is now 28-10.""")
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print(f"""\nwell done on scoring that last play but the defense have the ball
            \nwith insufficient amount of time left they have taken a knee and ran the clock down to 0
            \nthis means that the final score of superbowl 51 is 28-10 to the Falcons
            \better luck next year""")
            time.sleep(2)
            fail()
            
        

    # Choose run
        elif level_8 in level_8_option_2:
            time.sleep(0.5)
            print(Fore.WHITE + Back.BLACK + """\nThe defence had the answer to stop you
            \nthe score is still 28-3.""")
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print("""\nunlucky on the play there but there is more bad news
            \nthe defense have the ball and with insufficient time on the clock 
            \nthe falcons are going to take a knee and run the clock to 0 
            \nthis means that the final score of superbowl 51 is 28-3 to the Falcons
            \nbetter luck next year""")
            time.sleep(2)
            fail()
            

        else:
            print("""\nyou did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
            
         

 #level 9
def level_9():
    #superbowl game level 9 
    time.sleep(3)
    print(Fore.BLUE +'-'*75)
    time.sleep(0.5)
    print(Fore.WHITE +'-'*75)
    time.sleep(0.5)
    print(Fore.RED +'-'*75)
    time.sleep(0.5)
    #patriots level 9 intro
    ("""\nWe are at that stage now where literally everything has to go in our favor 
    \nYou have shown some grit and a never give up attitude so far
    \nHowever you are still trailing by a lengthy margin""") 
    time.sleep(3)
    print(Fore.BLUE)
    #patriots level 9 scenario 
    print(f"""\nLets get this play in the bag 4th and goal here we go
    \nThe recievers are hungry as ever and look like they still have fresh legs
    \nBut we know that there is another running back in your line up
    \nThat being said we know all about Falcons having a strong run defense""")

    level_9_option_1 = ['1','pass','option 1','pass play']
    level_9_option_2 = ['2','run','option 2','run play']
    loop=2
    #Level 9 Choice
    while loop>=0:
        level_9 = input('Do you want to go for a run or pass play? \t')
    
     #Choose pass
        if level_9 in level_9_option_1:
            time.sleep(0.5)
            print(Fore.BLUE + Back.WHITE + """\nTOUCHDOWN! the defence was a bit bamboozled by you well played
            \nKeep the momentum going'
            \nThe score is now 28-17.""")
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print(f"""\nWell done on scoring that last play but the defense have the ball
            \nWith insufficient amount of time left they have taken a knee and run the clock to 0
            \nThis means that the final score of superbowl 51 is 28-17 to the Falcons""")
            time.sleep(2)
            fail()
            
        

    # Choose run
        elif level_9 in level_9_option_2:
            time.sleep(0.5)
            print(Fore.WHITE + Back.BLUE + """\nThe defence had the answer to stop you
            \Tthe score is still 28-10.""")
            print(Fore.RESET + Back.RESET)
            time.sleep(2)
            print("""\nUnlucky on the play there but there is more bad news
            \nThe defense have the ball and with insufficient time on the clock 
            \nthe Falcons are going to take a knee and run the clock to 0 
            \nThis means that the final score of superbowl 51 is 28-10 to the Falcons""")
            time.sleep(2)
            fail()
           
        #invalid input
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
            
             
     
    


#level 6
def level_6():
    #superbowl game level 6
    time.sleep(3)
    print(Fore.BLUE +'-'*75)
    time.sleep(0.5)
    print(Fore.WHITE +'-'*75)
    time.sleep(0.5)
    print(Fore.RED +'-'*75)
    time.sleep(0.5)
    
    #patriots level 6 intro 
    print(f"""\nThere aren't many more plays left so you need to make every play a touchdown
    \nif not then your team will lose the superbowl and the chance to have the biggest comeback""")
    time.sleep(3)
    #patriots level 6 scenario
    print(Fore.BLUE+"""\nhere we go again, another 4th and goal situation
    \nthe recievers are still looking fresh and sharp
    \nhowever there is a differnt running back in your offensive line up
    \nfalcons are still more confident that they can stop the run game""")
    print(Fore.RESET + Back.RESET)
    
    level_6_option_1 = ['1','pass','option 1','pass play']
    level_6_option_2 = ['2','run','option 2','run play']
    loop=2#stopping users from invalid input
    #Level 6 Choice
    while loop>=0:
        level_6 = input('Do you want to go for a run or pass play? \t')
    
     #Choose pass
        if level_6 in level_6_option_1:
            time.sleep(0.5)
            print(Fore.WHITE + Back.BLUE + """\nTOUCHDOWN! the defence was a bit bamboozled by you well played'
            \nkeep the momentum going!     
            \nthe score is now 28-17.""")
            print(Fore.RESET + Back.RESET)
            level_13()
            break
        

    # Choose run
        elif level_6 in level_6_option_2:
            time.sleep(0.5)
            print(Fore.WHITE + Back.BLUE + """\nThe defence had the answer to stop you
            \nthe score is still 28-10.""")
            print(Fore.RESET + Back.RESET)
            level_12()
            break

        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
            
           
        
#level 7 
def level_7():
    #superbowl game level 7
    time.sleep(3)
    print(Fore.BLUE +'-'*75)
    time.sleep(0.5)
    print(Fore.WHITE +'-'*75)
    time.sleep(0.5)
    print(Fore.RED +'-'*75)
    time.sleep(0.5)
    
    #patriots level 7 intro
    print(f"""\nYou are doing great so far, you have picked up momentum
    \nThe Atlanta Falcons defense seem nervous, the tides are slowly changing
    \nThe bookies who worte you off are starting to think otherwise""")
    time.sleep(3)
    #patriots level 7 scenario
    print(f"""\nHere we go again it is 4th and goal
    \nYou have been using your quarterback and recievers well in the pressure situations
    \nYou have also figured out that Atlanta has a strong run defense""")
    
    level_7_option_1 = ['1','pass','option 1','pass play']
    level_7_option_2 = ['2','run','option 2','run play']
    loop=2#stopping user input 
     #Level 7 Choice
    while loop>=0:
        level_7 = input('Do you want to go for a run or pass play? \t')
       
    # Choose pass
        if level_7 in level_7_option_1:
            time.sleep(0.5)
            print(Fore.BLUE + Back.BLACK + """\nTOUCHDOWN! The defence was a bit bamboozled by you well played
            \nOn top of that you scored the 2-point conversion with yet another good pass play     
            \nThe score is now 28-25.""")
            print(Fore.RESET + Back.RESET)
            level_15()
            break
        

    # Choose run
        elif level_7 in level_7_option_2:
            time.sleep(0.5)
            print(Fore.WHITE + Back.BLUE + """\nThe defence had the answer to stop you
            \nThe score is still 28-17.""")
            print(Fore.RESET + Back.RESET)
            level_14()
            break
         #invalid input 
        else:
            print("""\nyou did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
            
        


#level 4
def level_4():
    #superbowl game level 5
    time.sleep(3)
    print(Fore.BLUE +'-'*75)
    time.sleep(0.5)
    print(Fore.WHITE +'-'*75)
    time.sleep(0.5)
    print(Fore.RED +'-'*75)
    time.sleep(0.5)
    
    #patriots level 4 intro 
    print(f"""\nThings have not worked out well for so far you are still 25 points behind
    \nA lot of catching up to do,so now it is important to score a touchdown now""")
    time.sleep(3)
    
   #patriots level 4 scenario
    print(f"""\nthe quarterback has not been involved when it matters the most so far 
    \nyour running game has not been churning out the yards in the crucial moments
    \nthe superbowl is starting to slip away so scoring is important""")
    
    level_4_option_1 = ['1','pass','option 1','pass play']
    level_4_option_2 = ['2','run','option 2','run play']
    loop=2#restricting user input
    # Level 4 Choice
    while loop>=0:
        level_4 = input('Do you want to go for a run or pass play? \t')
       
    # Choose pass
        if level_4 in level_4_option_1:
            time.sleep(0.5)
            print(Fore.BLUE + Back.BLACK + """\nTOUCHDOWN! the defence was a bit bamboozled by you well played
            \nthe score is now 28-10.""")
            print(Fore.RESET + Back.RESET)
            level_9()
            break 
       

    # Choose run
        elif level_4 in level_4_option_2:
            time.sleep(0.5)
            print(Fore.WHITE + Back.BLACK + """\nThe defence had the answer to stop you
            \nThe score is still 28-3.""")
            print(Fore.RESET + Back.RESET)
            level_8()
            break
           
    
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
    
        loop -= 1
        if loop == 0:
            invalid_input()
           
        
        
     
 
 
 #level 5
def level_5():
    #superbowl game-level 5
    time.sleep(3)
    print(Fore.BLUE +'-'*75)
    time.sleep(0.5)
    print(Fore.WHITE +'-'*75)
    time.sleep(0.5)
    print(Fore.RED +'-'*75)
    time.sleep(0.5)
 
   # patriots level 5 intro
    print(f"""\nWell done on scoring in the last play however you still trail by 18
    \nMaking every play count is important now since you are running out of time
    \nOn top of that you do not have many plays left""")
    time.sleep(3)
    print(Fore.BLUE)
    #patriots level 5- scenario
    print(f"""\nOnce again it is 4th and goal 
    \nThe opposition defence is not sure if you are going to pass or run the ball
    \nThe passing game has worked well so far and the defence is stil feeling good about stopping the run""")
    
    level_5_option_1 = ['1','pass','option 1','pass play']
    level_5_option_2 = ['2','run','option 2','run play']
    loop=2#restricting user input  
    # Level 5 Choice
    while loop>=0:
        level_5 = input('Do you want to go for a run or pass play? \t')
       
    # Choose pass
        if level_5 in level_5_option_1:
            time.sleep(0.5)
            print(Fore.WHITE + Back.BLACK + """\nTOUCHDOWN! the defence was a bit bamboozled by you well played
            \nthe score is now 28-17.""")
            print(Fore.RESET + Back.RESET)
            level_11()
            break
        

    # Choose run
        elif level_5 in level_5_option_2:
            time.sleep(0.5)
            print(Fore.WHITE + Back.BLACK + """\nthe defence had the answer to stop you
            \nthe score is still 28-10.""")
            print(Fore.RESET + Back.RESET)
            level_10()
            break
      
    #if user inputs wrong fucntion 
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
                invalid_input()
                break
        


#level 2 
def level_2():
    #superbowl game-Level 2
    time.sleep(3)
    print(Fore.BLUE +'-'*75)
    time.sleep(0.5)
    print(Fore.WHITE +'-'*75)
    time.sleep(0.5)
    print(Fore.RED +'-'*75)
    time.sleep(0.5)
    
    # patriots level 2 - intro
    print(f"""\nYou did not score in the last play but it is important now that you score in every play
    \nYou need to ensure that you make every play count now because you still trail by 25 points""")
    time.sleep(3)
    print(Fore.BLUE)
    #patriots level 2 - scenario 
    print(f"""\nThe defence read your run play very well and forced a turnover last time 
    \nThe oppositon looks poised to do the same again
    \nyour quaterback and receivers are lacking involvement in these pressure situations
    \nThe choice is yours, do you want to use a pass play or a run play call""")
    
    level_2_option_1 = ['1','pass','option 1','pass play']
    level_2_option_2 = ['2','run','option 2','run play']
    loop=2#restricting user invalid input 
    # Level 2 Choice
    while loop>=0:  
        level_2 = input('Do you want to go for a run or pass play? \t')
     
     
     # Choose pass
        if level_2 in level_2_option_1:
            time.sleep(0.9)
            print(Fore.WHITE + Back.BLACK + """\nTOUCHDOWN! the defence was a bit bamboozled by you well played
            \nthe score is now 28-10.""")
            print(Fore.RESET + Back.RESET)
            level_5()
            break
        

    # Choose run
        elif level_2 in level_2_option_2:
            time.sleep(0.9)
            print(Fore.WHITE + Back.BLACK + """\nthe defence had the answer to stop you
            \nthe score is still 28-3.""")
            print(Fore.RESET + Back.RESET)
            level_4()
            break
          
        #if user inputs wrong fucntion 
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
            break


#level 3
def level_3():
    # superbowl game-Level 3
    time.sleep(4)
    print(Fore.BLUE +'-'*75)
    time.sleep(0.5)
    print(Fore.WHITE +'-'*75)
    time.sleep(0.5)
    print(Fore.RED +'-'*75)
    time.sleep(0.5)
    
    # patriots level 3 - intro 
    print(f"""\nYou managed to score on the previous play and trim the lead down to 18
    \nA few more scoring plays and the you will be lifting the trophy
    \nYou have not got much time left so you need to make every play count""")
    time.sleep(1)
    # patriots level 3 scenario
    print(Fore.BLUE+f"""\nHere we go 4th and goal again
    \nThe opposition looks like they have lined up to stop the running back
    \nYour recievers and quarterback are both looking sharp
    \nThe choice is up to if you want to use a pass or run play""")
    
    level_3_option_1 = ['1','pass','option 1','pass play']
    level_3_option_2 = ['2','run','option 2','run play']
    loop = 2 #restricting user from invalid input    
    # Level 3 Choice
    while loop >=0:
        level_3 = input('Do you want to go for a run or pass play? \t')
     
     
        # Choose pass
        if level_3 in level_3_option_1:
            time.sleep(0.5)
            print(Fore.WHITE + Back.BLACK + """\nThe defence  could not read your mind
           \nTouchdown
           \nThe score is now 28-17.""")
            print(Fore.RESET + Back.RESET)
            level_7()
            break


            # Choose run
        elif level_3 in level_3_option_2:
            time.sleep(0.5)
            print(Fore.WHITE + Back.BLACK + """\nThe defence had the answer to stop you
            \nThe score is still 28-10.""")
            print(Fore.RESET + Back.RESET)
            level_6()
            break

            #if user inputs wrong fucntion 
        else:
            print("""you did not follow the Instructions
                  \nthat's a flag on the play
                  \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
            break


#Level 1
def level_1():
    
    time.sleep(4)
    print(Fore.BLUE +'-'*75)
    time.sleep(0.5)
    print(Fore.WHITE +'-'*75)
    time.sleep(0.5)
    print(Fore.RED +'-'*75)
    time.sleep(0.5)

   # patriots  Level 1 - Intro
    print(Fore.WHITE)
    print(f"""\nYou are down 28-3 this is going to be a long game for you 
    \nHowever there have been many comebacks before so this is very possible
    \nYour goal is to score as many touchdowns as possible for your team""")
     # Patriots level 1 scenario
    ("""\nYour run game has been weak and predictable your recivers are urging for a pass""")
    time.sleep(1)
    print(Fore.YELLOW +'\nTime to decide if you want to go for a pass or run play?\t')
    print(Fore.RESET)
    
    #level 1 option list 
    level_1_option_1 = ['1','pass','option 1','pass play']
    level_1_option_2 = ['2','run','option 2','run play']
    loop = 2 #restricting user from invalid input  
    # Level 1 Choice
    while loop >=0:
        level_1 = input('Do you want to go for a run or pass play? \t')

        # Choose pass
        if level_1 in level_1_option_1:
            time.sleep(0.9)
            print(Fore.WHITE + Back.BLACK + """\nThe defence had no answers to stop you from scoring a touchdown'
            \nThe score is now 28-10.""")
            print(Fore.RESET + Back.RESET)
            level_3()
            break
         # Choose run
        elif level_1 in level_1_option_2:
            time.sleep(0.9)
            print(Fore.WHITE + Back.BLACK + '\nThe defence read your mind and forced the turnover'
            '\nThe score is still 28-3.')
            print(Fore.RESET + Back.RESET)
            level_2()
            break
       #invalid input
        else:
            print("""you did not follow the Instructions
           \nthat's a flag on the play
           \nplease try again""")
        loop -= 1
        if loop == 0:
            invalid_input()
           
        


#Choose level 0 Answer 
while True:
    ans=input("Do you have much knowledge about American Football?\t") 
    #ANS =YES
    if ans in question_1_option_1:
        print("""\nWell then this should be a breeze for you 
       \nBut don't get too complacent though!
       \nYou will need a bit of luck to win as well""")
        time.sleep(2)
        print("""\nPlease answer all questions as 1 or 2
       \nOption 1 will always be the pass play option 
       \nOption 2 will alwyas be the run play option""") 
        level_1()      
        break       

    #ANS=NO               
    elif ans in question_1_option_2:
        print("""\nNo need to worry you stil have this in the bag 
       \nJust be sure to read the scenarios and make a judgement call from there!""")
        time.sleep(2)
        print("""\nPlease answer all questions as 1 or 2
       \nOption 1 will always be the pass play option 
       \nOption 2 will alwyas be the run play option""") 
        level_1()      
        break     
    #invalid input
    else:
        print("""\nconsider this as a warning as this is just a sample test
        \nif you exhibit this behavior of unsportsman like conduct any further then you will likely be ejected from the game for unsportsman like conduct""")
        level_1()
        break
# Out:
# --------------------------------------------------
# Welcome to the 2017 superbowl at the NRG Stadium in Houston
# --------------------------------------------------
#  We are well poised for one of the best fourth quarters in superbowl history
#
#
# Instructions for the game:
#
# Today you will be playing the role of a nfl head coach of New England Patriots.
#
# You will be asked to make offensive playcalls which will determine if your team scores
#
# Not to mention the prestige Vince Lombardi Trophy and a superbowl ring
#
# one important instruction to follow,
#
# For every scenario please in the game please input one the following if you choose pass:
#
# '1','pass','option 1','pass play'
#
# if you choose run then input one of the following:
#
# '2','run','option 2','run play'
# Failure to do so in the first attempt will give you a warning
#
# you will then be aksed to try again
#
# failure to do so in the second attempt will eject you from the game and you will lose
#
# ...

# %%
conda install colorama
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - colorama
#
#
# The following NEW packages will be INSTALLED:
#
#   colorama           pkgs/main/noarch::colorama-0.4.4-pyhd3eb1b0_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
